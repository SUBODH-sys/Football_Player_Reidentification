# %%
# !pip install ultralytics
# !pip install deep_sort_realtime
# !pip install git+https://github.com/KaiyangZhou/deep-person-reid.git
# Out:
# Requirement already satisfied: ultralytics in /usr/local/lib/python3.11/dist-packages (8.3.160)
# Requirement already satisfied: numpy>=1.23.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.0.2)
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (3.10.0)
# Requirement already satisfied: opencv-python>=4.6.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (4.11.0.86)
# Requirement already satisfied: pillow>=7.1.2 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (11.2.1)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (6.0.2)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.32.3)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (1.15.3)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.6.0+cu124)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (0.21.0+cu124)
# Requirement already satisfied: tqdm>=4.64.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (4.67.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from ultralytics) (5.9.5)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.11/dist-packages (from ultralytics) (9.0.0)
# Requirement already satisfied: pandas>=1.1.4 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.2.2)
# Requirement already satisfied: ultralytics-thop>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.0.14)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (4.58.4)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1.4->ultralytics) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1.4->ultralytics) (2025.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (2025.6.15)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (4.14.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (2025.3.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.2)
# Requirement already satisfied: deep_sort_realtime in /usr/local/lib/python3.11/dist-packages (1.3.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from deep_sort_realtime) (2.0.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from deep_sort_realtime) (1.15.3)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.11/dist-packages (from deep_sort_realtime) (4.11.0.86)
# Collecting git+https://github.com/KaiyangZhou/deep-person-reid.git
#   Cloning https://github.com/KaiyangZhou/deep-person-reid.git to /tmp/pip-req-build-snbv87_c
#   Running command git clone --filter=blob:none --quiet https://github.com/KaiyangZhou/deep-person-reid.git /tmp/pip-req-build-snbv87_c
#   Resolved https://github.com/KaiyangZhou/deep-person-reid.git to commit 566a56a2cb255f59ba75aa817032621784df546a
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from torchreid==1.4.0) (2.0.2)
# Requirement already satisfied: Cython in /usr/local/lib/python3.11/dist-packages (from torchreid==1.4.0) (3.0.12)
# Requirement already satisfied: h5py in /usr/local/lib/python3.11/dist-packages (from torchreid==1.4.0) (3.14.0)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.11/dist-packages (from torchreid==1.4.0) (11.2.1)
# Requirement already satisfied: six in /usr/local/lib/python3.11/dist-packages (from torchreid==1.4.0) (1.17.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from torchreid==1.4.0) (1.15.3)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.11/dist-packages (from torchreid==1.4.0) (4.11.0.86)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from torchreid==1.4.0) (3.10.0)
# Requirement already satisfied: tb-nightly in /usr/local/lib/python3.11/dist-packages (from torchreid==1.4.0) (2.20.0a20250628)
# Requirement already satisfied: future in /usr/local/lib/python3.11/dist-packages (from torchreid==1.4.0) (1.0.0)
# Requirement already satisfied: yacs in /usr/local/lib/python3.11/dist-packages (from torchreid==1.4.0) (0.1.8)
# Requirement already satisfied: gdown in /usr/local/lib/python3.11/dist-packages (from torchreid==1.4.0) (5.2.0)
# Requirement already satisfied: flake8 in /usr/local/lib/python3.11/dist-packages (from torchreid==1.4.0) (7.3.0)
# Requirement already satisfied: yapf in /usr/local/lib/python3.11/dist-packages (from torchreid==1.4.0) (0.43.0)
# Requirement already satisfied: isort==4.3.21 in /usr/local/lib/python3.11/dist-packages (from torchreid==1.4.0) (4.3.21)
# Requirement already satisfied: imageio in /usr/local/lib/python3.11/dist-packages (from torchreid==1.4.0) (2.37.0)
# Requirement already satisfied: chardet in /usr/local/lib/python3.11/dist-packages (from torchreid==1.4.0) (5.2.0)
# Requirement already satisfied: mccabe<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from flake8->torchreid==1.4.0) (0.7.0)
# Requirement already satisfied: pycodestyle<2.15.0,>=2.14.0 in /usr/local/lib/python3.11/dist-packages (from flake8->torchreid==1.4.0) (2.14.0)
# Requirement already satisfied: pyflakes<3.5.0,>=3.4.0 in /usr/local/lib/python3.11/dist-packages (from flake8->torchreid==1.4.0) (3.4.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.11/dist-packages (from gdown->torchreid==1.4.0) (4.13.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from gdown->torchreid==1.4.0) (3.18.0)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.11/dist-packages (from gdown->torchreid==1.4.0) (2.32.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from gdown->torchreid==1.4.0) (4.67.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->torchreid==1.4.0) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->torchreid==1.4.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->torchreid==1.4.0) (4.58.4)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->torchreid==1.4.0) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->torchreid==1.4.0) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->torchreid==1.4.0) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->torchreid==1.4.0) (2.9.0.post0)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.11/dist-packages (from tb-nightly->torchreid==1.4.0) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.11/dist-packages (from tb-nightly->torchreid==1.4.0) (1.73.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.11/dist-packages (from tb-nightly->torchreid==1.4.0) (3.8.2)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in /usr/local/lib/python3.11/dist-packages (from tb-nightly->torchreid==1.4.0) (5.29.5)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.11/dist-packages (from tb-nightly->torchreid==1.4.0) (75.2.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from tb-nightly->torchreid==1.4.0) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from tb-nightly->torchreid==1.4.0) (3.1.3)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.11/dist-packages (from yacs->torchreid==1.4.0) (6.0.2)
# Requirement already satisfied: platformdirs>=3.5.1 in /usr/local/lib/python3.11/dist-packages (from yapf->torchreid==1.4.0) (4.3.8)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.11/dist-packages (from werkzeug>=1.0.1->tb-nightly->torchreid==1.4.0) (3.0.2)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4->gdown->torchreid==1.4.0) (2.7)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4->gdown->torchreid==1.4.0) (4.14.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests[socks]->gdown->torchreid==1.4.0) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests[socks]->gdown->torchreid==1.4.0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests[socks]->gdown->torchreid==1.4.0) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests[socks]->gdown->torchreid==1.4.0) (2025.6.15)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.11/dist-packages (from requests[socks]->gdown->torchreid==1.4.0) (1.7.1)

# %%
import cv2
import numpy as np
from ultralytics import YOLO
from deep_sort_realtime.deepsort_tracker import DeepSort
from collections import defaultdict
import matplotlib.pyplot as plt
import seaborn as sns
import os
from math import hypot
import torch
import torchvision.transforms as transforms
from torchreid.models import osnet_x1_0  # OSNet variant
from sklearn.metrics.pairwise import cosine_similarity

# %%
video_path = "/content/15sec_input_720p.mp4"
model_path = "/content/best.pt"
model = YOLO(model_path)
tracker = DeepSort(max_age=60, n_init=5, max_iou_distance=0.3)

# %%
cap = cv2.VideoCapture(video_path)
width, height = int(cap.get(3)), int(cap.get(4))
fps = cap.get(cv2.CAP_PROP_FPS)
out = cv2.VideoWriter('output.mp4', cv2.VideoWriter_fourcc(*'mp4v'), fps, (width, height))

# %%
# Scaling factors for YOLO inference (384x640) to original (1280x720)
input_width, input_height = 384, 640
scale_x = width / input_width
scale_y = height / input_height

# %%
player_tracks = defaultdict(list)
unique_ids = set()
player_speeds = defaultdict(list)
player_embeddings = {}
player_box_sizes = defaultdict(list)
passes = []
frame_idx = 0

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
reid_model = osnet_x1_0(pretrained=True).eval().to(device)
extract_transform = transforms.Compose([
    transforms.ToPILImage(),
    transforms.Resize((256, 128)),  # OSNet expects 256x128 input
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])
# Out:
# Successfully loaded imagenet pretrained weights from "/root/.cache/torch/checkpoints/osnet_x1_0_imagenet.pth"

# %%
def get_embedding(crop):
    if crop.size == 0:
        return np.zeros(512)  # OSNet x1.0 outputs 512-dimensional features
    tensor = extract_transform(crop).unsqueeze(0).to(device)
    with torch.no_grad():
        return reid_model(tensor).cpu().numpy().flatten()

# %%
def match_id(crop, known_embeddings, threshold=0.75):  # Adjusted threshold for OSNet
    emb = get_embedding(crop).reshape(1, -1)
    best_id, best_score = None, 0
    for pid, ref_emb in known_embeddings.items():
        sim = cosine_similarity(emb, ref_emb.reshape(1, -1))[0][0]
        if sim > best_score and sim > threshold:
            best_id = pid
            best_score = sim
    return best_id

# %%
def smooth_box(prev_box, curr_box, alpha=0.7):
    if prev_box is None:
        return curr_box
    l1, t1, w1, h1 = prev_box
    l2, t2, w2, h2 = curr_box
    l = int(alpha * l1 + (1 - alpha) * l2)
    t = int(alpha * t1 + (1 - alpha) * t2)
    w = int(alpha * w1 + (1 - alpha) * w2)
    h = int(alpha * h1 + (1 - alpha) * h2)
    return [l, t, w, h]

# %%
# Parameters
conf_threshold = 0.8  # Adjust confidence threshold
nms_threshold = 0.2   # Adjust NMS threshold
frame_width = 640
frame_height = 384

track_history = {}

while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        print(f"Video ended at frame {frame_idx}")
        break
    frame_idx += 1

    # Preprocess frame for YOLO (resize to 384x640)
    input_frame = cv2.resize(frame, (input_width, input_height))
    results = model(input_frame)[0]
    detections = []
    ball_position = None

    for r in results.boxes.data.tolist():
        x1, y1, x2, y2, score, cls = r
        cls = int(cls)
        # Scale bounding box to original frame size
        x1, y1, x2, y2 = x1 * scale_x, y1 * scale_y, x2 * scale_x, y2 * scale_y
        bbox = [x1, y1, x2 - x1, y2 - y1]
        w, h = x2 - x1, y2 - y1
        if score < conf_threshold:  # Skip low-confidence detections
            continue
        if w * h < 1000:  # Minimum box size filter
            continue
        if cls == 2:  # player
            if h / w < 1.5:
                h = int(w * 1.5)  # Adjusted aspect ratio
                y2 = y1 + h
            detections.append((bbox, score, 'player'))
        elif cls == 0:  # ball
            cx, cy = int((x1 + x2)/2), int((y1 + y2)/2)
            ball_position = (cx, cy)
            cv2.circle(frame, (cx, cy), 7, (0, 0, 255), -1)
            cv2.putText(frame, 'Ball', (cx + 10, cy), cv2.FONT_HERSHEY_SIMPLEX, 0.6, (0, 0, 255), 2)

    tracks = tracker.update_tracks(detections, frame=frame)

    for track in tracks:
        if not track.is_confirmed():
            continue

        track_id = track.track_id
        l, t, r, b = map(int, track.to_ltrb())
        cx = int((l + r) / 2)
        cy = int((t + b) / 2)
        w, h = r - l, b - t

        # Smooth bounding box
        prev_box = player_box_sizes[track_id][-1] if player_box_sizes[track_id] else None
        smoothed_box = smooth_box(prev_box, [l, t, w, h])
        l, t, w, h = smoothed_box
        r, b = l + w, t + h

        # Debug centroid coordinates
        print(f"Frame {frame_idx}, Track {track_id}: cx={cx}, cy={cy}")

        # Re-ID embedding with OSNet
        crop = frame[t:b, l:r]
        if crop.size > 0:
            emb = get_embedding(crop)
            if track_id not in player_embeddings or len(player_embeddings[track_id]) == 0:
                player_embeddings[track_id] = emb
            else:
                match = match_id(crop, {k: v for k, v in player_embeddings.items() if k != track_id})
                if match and cosine_similarity(emb.reshape(1, -1), player_embeddings[match].reshape(1, -1))[0][0] > 0.75:
                    track_id = match

        # Draw
        cv2.rectangle(frame, (l, t), (r, b), (0, 255, 0), 2)
        cv2.putText(frame, f'Player {track_id}', (l, t - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.6, (0, 255, 0), 2)

    out.write(frame)

cap.release()
out.release()

# Analysis Plots
print(f"\n Tracking Complete: {len(unique_ids)} unique players re-identified.")
# Out:
# 0: 640x384 32 players, 2 referees, 68.9ms
# Speed: 2.6ms preprocess, 68.9ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 33 players, 2 referees, 36.6ms
# Speed: 3.7ms preprocess, 36.6ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 37 players, 2 referees, 42.6ms
# Speed: 2.0ms preprocess, 42.6ms inference, 4.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 34 players, 2 referees, 37.9ms
# Speed: 4.0ms preprocess, 37.9ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 35 players, 2 referees, 41.3ms
# Speed: 5.1ms preprocess, 41.3ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 35 players, 3 referees, 44.9ms
# Speed: 1.9ms preprocess, 44.9ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 42 players, 3 referees, 36.9ms
# Speed: 1.9ms preprocess, 36.9ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 32 players, 2 referees, 80.0ms
# Speed: 1.9ms preprocess, 80.0ms inference, 14.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 34 players, 2 referees, 62.3ms
# Speed: 2.0ms preprocess, 62.3ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 goalkeeper, 33 players, 3 referees, 71.6ms
# Speed: 1.8ms preprocess, 71.6ms inference, 11.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 29 players, 2 referees, 36.5ms
# Speed: 1.9ms preprocess, 36.5ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 32 players, 1 referee, 64.2ms
# Speed: 1.9ms preprocess, 64.2ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 37 players, 2 referees, 43.3ms
# Speed: 1.7ms preprocess, 43.3ms inference, 9.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 37 players, 2 referees, 44.6ms
# Speed: 1.8ms preprocess, 44.6ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 29 players, 2 referees, 50.8ms
# Speed: 2.2ms preprocess, 50.8ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 29 players, 3 referees, 73.4ms
# Speed: 2.1ms preprocess, 73.4ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 27 players, 3 referees, 63.5ms
# Speed: 2.0ms preprocess, 63.5ms inference, 10.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 28 players, 1 referee, 58.9ms
# Speed: 1.9ms preprocess, 58.9ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 27 players, 2 referees, 42.2ms
# Speed: 1.9ms preprocess, 42.2ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 39 players, 3 referees, 46.2ms
# Speed: 1.9ms preprocess, 46.2ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 34 players, 1 referee, 42.8ms
# Speed: 2.0ms preprocess, 42.8ms inference, 4.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 28 players, 2 referees, 64.0ms
# Speed: 4.8ms preprocess, 64.0ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 27 players, 1 referee, 150.7ms
# Speed: 2.3ms preprocess, 150.7ms inference, 17.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 28 players, 2 referees, 72.3ms
# Speed: 1.9ms preprocess, 72.3ms inference, 7.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 25 players, 2 referees, 41.8ms
# Speed: 3.7ms preprocess, 41.8ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 30 players, 3 referees, 60.4ms
# Speed: 2.4ms preprocess, 60.4ms inference, 21.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 29 players, 3 referees, 45.0ms
# Speed: 2.0ms preprocess, 45.0ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 27 players, 3 referees, 39.3ms
# Speed: 1.9ms preprocess, 39.3ms inference, 7.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 26 players, 4 referees, 54.3ms
# Speed: 2.1ms preprocess, 54.3ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 21 players, 3 referees, 40.4ms
# Speed: 7.9ms preprocess, 40.4ms inference, 7.0ms postprocess per image at shape (1, 3, 640, 384)
# Frame 30, Track 93: cx=1186, cy=167
#
# 0: 640x384 23 players, 1 referee, 39.5ms
# Speed: 3.5ms preprocess, 39.5ms inference, 2.8ms postprocess per image at shape (1, 3, 640, 384)
# Frame 31, Track 93: cx=1187, cy=168
#
# 0: 640x384 24 players, 2 referees, 39.1ms
# Speed: 1.9ms preprocess, 39.1ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 384)
# Frame 32, Track 93: cx=1189, cy=168
#
# 0: 640x384 27 players, 3 referees, 39.0ms
# Speed: 1.7ms preprocess, 39.0ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 384)
# Frame 33, Track 93: cx=1190, cy=168
#
# 0: 640x384 24 players, 2 referees, 43.1ms
# Speed: 1.7ms preprocess, 43.1ms inference, 8.5ms postprocess per image at shape (1, 3, 640, 384)
# Frame 34, Track 93: cx=1191, cy=168
#
# 0: 640x384 34 players, 1 referee, 50.2ms
# Speed: 4.2ms preprocess, 50.2ms inference, 2.7ms postprocess per image at shape (1, 3, 640, 384)
# Frame 35, Track 93: cx=1193, cy=168
#
# 0: 640x384 26 players, 1 referee, 39.0ms
# Speed: 2.1ms preprocess, 39.0ms inference, 2.7ms postprocess per image at shape (1, 3, 640, 384)
# Frame 36, Track 93: cx=1194, cy=168
#
# 0: 640x384 30 players, 2 referees, 40.7ms
# Speed: 2.2ms preprocess, 40.7ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 384)
# Frame 37, Track 93: cx=1196, cy=168
#
# 0: 640x384 32 players, 2 referees, 55.7ms
# Speed: 2.0ms preprocess, 55.7ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 384)
# Frame 38, Track 93: cx=1197, cy=168
#
# 0: 640x384 28 players, 1 referee, 39.2ms
# Speed: 2.0ms preprocess, 39.2ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 384)
# Frame 39, Track 93: cx=1198, cy=169
#
# 0: 640x384 31 players, 2 referees, 40.9ms
# Speed: 1.8ms preprocess, 40.9ms inference, 2.8ms postprocess per image at shape (1, 3, 640, 384)
# Frame 40, Track 93: cx=1200, cy=169
#
# 0: 640x384 29 players, 2 referees, 46.1ms
# Speed: 1.8ms preprocess, 46.1ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 384)
# Frame 41, Track 93: cx=1201, cy=169
#
# 0: 640x384 31 players, 1 referee, 45.4ms
# Speed: 1.6ms preprocess, 45.4ms inference, 3.8ms postprocess per image at shape (1, 3, 640, 384)
# Frame 42, Track 93: cx=1203, cy=169
#
# 0: 640x384 30 players, 1 referee, 47.7ms
# Speed: 2.1ms preprocess, 47.7ms inference, 2.8ms postprocess per image at shape (1, 3, 640, 384)
# Frame 43, Track 93: cx=1204, cy=169
#
# 0: 640x384 29 players, 2 referees, 48.1ms
# Speed: 1.6ms preprocess, 48.1ms inference, 4.6ms postprocess per image at shape (1, 3, 640, 384)
# Frame 44, Track 93: cx=1205, cy=169
#
# 0: 640x384 24 players, 2 referees, 64.1ms
# Speed: 2.0ms preprocess, 64.1ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 384)
# Frame 45, Track 93: cx=1207, cy=169
#
# 0: 640x384 23 players, 2 referees, 50.1ms
# Speed: 2.1ms preprocess, 50.1ms inference, 2.7ms postprocess per image at shape (1, 3, 640, 384)
# Frame 46, Track 93: cx=1189, cy=177
#
# 0: 640x384 29 players, 4 referees, 50.7ms
# Speed: 1.6ms preprocess, 50.7ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 384)
# Frame 47, Track 93: cx=1189, cy=177
#
# 0: 640x384 26 players, 2 referees, 51.6ms
# Speed: 2.2ms preprocess, 51.6ms inference, 2.7ms postprocess per image at shape (1, 3, 640, 384)
# Frame 48, Track 93: cx=1187, cy=177
#
# 0: 640x384 23 players, 2 referees, 52.2ms
# Speed: 2.1ms preprocess, 52.2ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 384)
# Frame 49, Track 93: cx=1186, cy=177
# Frame 49, Track 121: cx=1036, cy=433
#
# 0: 640x384 29 players, 1 referee, 53.5ms
# Speed: 1.8ms preprocess, 53.5ms inference, 4.3ms postprocess per image at shape (1, 3, 640, 384)
# Frame 50, Track 93: cx=1184, cy=177
# Frame 50, Track 121: cx=1032, cy=435
#
# 0: 640x384 29 players, 1 referee, 67.6ms
# Speed: 2.3ms preprocess, 67.6ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 384)
# Frame 51, Track 93: cx=1183, cy=178
# Frame 51, Track 121: cx=1028, cy=437
#
# 0: 640x384 30 players, 2 referees, 60.9ms
# Speed: 4.8ms preprocess, 60.9ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 384)
# Frame 52, Track 93: cx=1182, cy=178
# Frame 52, Track 121: cx=1021, cy=439
#
# 0: 640x384 21 players, 1 referee, 66.1ms
# Speed: 4.0ms preprocess, 66.1ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 384)
# Frame 53, Track 93: cx=1182, cy=179
# Frame 53, Track 121: cx=1016, cy=441
#
# 0: 640x384 25 players, 1 referee, 66.2ms
# Speed: 2.3ms preprocess, 66.2ms inference, 2.9ms postprocess per image at shape (1, 3, 640, 384)
# Frame 54, Track 93: cx=1181, cy=179
# Frame 54, Track 121: cx=1011, cy=442
#
# 0: 640x384 27 players, 2 referees, 67.5ms
# Speed: 1.9ms preprocess, 67.5ms inference, 3.4ms postprocess per image at shape (1, 3, 640, 384)
# Frame 55, Track 93: cx=1181, cy=179
# Frame 55, Track 121: cx=1007, cy=444
#
# 0: 640x384 24 players, 1 referee, 67.5ms
# Speed: 2.2ms preprocess, 67.5ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 384)
# Frame 56, Track 93: cx=1180, cy=180
# Frame 56, Track 121: cx=1003, cy=446
#
# 0: 640x384 29 players, 1 referee, 66.0ms
# Speed: 2.2ms preprocess, 66.0ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 384)
# Frame 57, Track 93: cx=1180, cy=180
# Frame 57, Track 121: cx=999, cy=447
#
# 0: 640x384 24 players, 65.3ms
# Speed: 1.7ms preprocess, 65.3ms inference, 2.8ms postprocess per image at shape (1, 3, 640, 384)
# Frame 58, Track 93: cx=1179, cy=181
# Frame 58, Track 121: cx=995, cy=449
#
# 0: 640x384 24 players, 2 referees, 64.7ms
# Speed: 1.8ms preprocess, 64.7ms inference, 8.9ms postprocess per image at shape (1, 3, 640, 384)
# Frame 59, Track 93: cx=1179, cy=181
# Frame 59, Track 121: cx=990, cy=451
#
# 0: 640x384 29 players, 1 referee, 64.8ms
# Speed: 2.0ms preprocess, 64.8ms inference, 2.7ms postprocess per image at shape (1, 3, 640, 384)
# Frame 60, Track 93: cx=1147, cy=187
# Frame 60, Track 121: cx=986, cy=453
#
# 0: 640x384 31 players, 2 referees, 71.4ms
# Speed: 2.2ms preprocess, 71.4ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 384)
# Frame 61, Track 93: cx=1141, cy=188
# Frame 61, Track 121: cx=982, cy=454
#
# 0: 640x384 26 players, 65.6ms
# Speed: 1.8ms preprocess, 65.6ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
# Frame 62, Track 93: cx=1135, cy=190
# Frame 62, Track 121: cx=995, cy=455
#
# 0: 640x384 35 players, 2 referees, 64.7ms
# Speed: 1.9ms preprocess, 64.7ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
# Frame 63, Track 93: cx=1129, cy=191
# Frame 63, Track 121: cx=992, cy=457
#
# 0: 640x384 35 players, 1 referee, 50.7ms
# Speed: 1.7ms preprocess, 50.7ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
# Frame 64, Track 93: cx=1124, cy=191
# Frame 64, Track 121: cx=990, cy=459
#
# 0: 640x384 28 players, 3 referees, 50.8ms
# Speed: 1.6ms preprocess, 50.8ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
# Frame 65, Track 93: cx=1122, cy=192
# Frame 65, Track 121: cx=986, cy=460
#
# 0: 640x384 32 players, 1 referee, 50.8ms
# Speed: 1.8ms preprocess, 50.8ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
# Frame 66, Track 93: cx=1122, cy=193
# Frame 66, Track 121: cx=984, cy=462
#
# 0: 640x384 29 players, 2 referees, 50.6ms
# Speed: 1.9ms preprocess, 50.6ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
# Frame 67, Track 93: cx=1121, cy=193
# Frame 67, Track 121: cx=981, cy=464
#
# 0: 640x384 36 players, 1 referee, 50.9ms
# Speed: 2.1ms preprocess, 50.9ms inference, 2.7ms postprocess per image at shape (1, 3, 640, 384)
# Frame 68, Track 93: cx=1118, cy=194
# Frame 68, Track 121: cx=978, cy=465
#
# 0: 640x384 31 players, 1 referee, 50.7ms
# Speed: 1.8ms preprocess, 50.7ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 384)
# Frame 69, Track 93: cx=1113, cy=194
# Frame 69, Track 121: cx=975, cy=467
#
# 0: 640x384 33 players, 50.7ms
# Speed: 1.7ms preprocess, 50.7ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 384)
# Frame 70, Track 93: cx=1109, cy=195
# Frame 70, Track 121: cx=972, cy=469
#
# 0: 640x384 30 players, 2 referees, 50.8ms
# Speed: 2.3ms preprocess, 50.8ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 384)
# Frame 71, Track 93: cx=1106, cy=196
# Frame 71, Track 121: cx=970, cy=470
#
# 0: 640x384 27 players, 1 referee, 50.7ms
# Speed: 1.9ms preprocess, 50.7ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 384)
# Frame 72, Track 93: cx=1104, cy=197
# Frame 72, Track 121: cx=967, cy=472
#
# 0: 640x384 33 players, 1 referee, 53.9ms
# Speed: 2.1ms preprocess, 53.9ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 384)
# Frame 73, Track 93: cx=1101, cy=198
# Frame 73, Track 121: cx=964, cy=473
#
# 0: 640x384 32 players, 3 referees, 54.1ms
# Speed: 1.8ms preprocess, 54.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
# Frame 74, Track 93: cx=1097, cy=199
# Frame 74, Track 121: cx=961, cy=475
#
# 0: 640x384 32 players, 2 referees, 57.6ms
# Speed: 2.0ms preprocess, 57.6ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 384)
# Frame 75, Track 93: cx=1094, cy=200
# Frame 75, Track 121: cx=958, cy=477
#
# 0: 640x384 33 players, 2 referees, 57.7ms
# Speed: 1.9ms preprocess, 57.7ms inference, 2.7ms postprocess per image at shape (1, 3, 640, 384)
# Frame 76, Track 93: cx=1089, cy=199
# Frame 76, Track 121: cx=956, cy=478
#
# 0: 640x384 31 players, 2 referees, 57.7ms
# Speed: 2.4ms preprocess, 57.7ms inference, 2.9ms postprocess per image at shape (1, 3, 640, 384)
# Frame 77, Track 93: cx=1084, cy=199
# Frame 77, Track 121: cx=953, cy=480
#
# 0: 640x384 32 players, 2 referees, 57.7ms
# Speed: 5.0ms preprocess, 57.7ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
# Frame 78, Track 93: cx=1080, cy=198
# Frame 78, Track 121: cx=950, cy=482
# Frame 78, Track 176: cx=963, cy=412
#
# 0: 640x384 41 players, 1 referee, 56.6ms
# Speed: 1.9ms preprocess, 56.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
# Frame 79, Track 93: cx=1078, cy=199
# Frame 79, Track 121: cx=947, cy=483
# Frame 79, Track 176: cx=959, cy=413
# Frame 79, Track 177: cx=1023, cy=357
#
# 0: 640x384 35 players, 3 referees, 53.0ms
# Speed: 1.5ms preprocess, 53.0ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
# Frame 80, Track 93: cx=1076, cy=199
# Frame 80, Track 121: cx=944, cy=485
# Frame 80, Track 176: cx=954, cy=412
# Frame 80, Track 177: cx=1019, cy=356
#
# 0: 640x384 34 players, 1 referee, 53.0ms
# Speed: 1.6ms preprocess, 53.0ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
# Frame 81, Track 93: cx=1075, cy=198
# Frame 81, Track 121: cx=941, cy=487
# Frame 81, Track 176: cx=950, cy=411
# Frame 81, Track 177: cx=1013, cy=360
#
# 0: 640x384 32 players, 2 referees, 53.0ms
# Speed: 1.7ms preprocess, 53.0ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
# Frame 82, Track 93: cx=1074, cy=199
# Frame 82, Track 121: cx=938, cy=488
# Frame 82, Track 176: cx=946, cy=409
# Frame 82, Track 177: cx=1008, cy=362
#
# 0: 640x384 28 players, 3 referees, 51.5ms
# Speed: 2.8ms preprocess, 51.5ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
# Frame 83, Track 93: cx=1071, cy=199
# Frame 83, Track 121: cx=936, cy=490
# Frame 83, Track 176: cx=942, cy=408
# Frame 83, Track 177: cx=1004, cy=368
#
# 0: 640x384 31 players, 2 referees, 51.5ms
# Speed: 2.3ms preprocess, 51.5ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
# Frame 84, Track 93: cx=1067, cy=198
# Frame 84, Track 121: cx=933, cy=492
# Frame 84, Track 176: cx=938, cy=410
# Frame 84, Track 177: cx=1002, cy=372
#
# 0: 640x384 38 players, 3 referees, 51.4ms
# Speed: 1.3ms preprocess, 51.4ms inference, 2.9ms postprocess per image at shape (1, 3, 640, 384)
# Frame 85, Track 93: cx=1063, cy=199
# Frame 85, Track 121: cx=930, cy=493
# Frame 85, Track 176: cx=934, cy=410
# Frame 85, Track 177: cx=1001, cy=373
#
# 0: 640x384 37 players, 1 referee, 51.4ms
# Speed: 2.2ms preprocess, 51.4ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 384)
# Frame 86, Track 93: cx=1059, cy=198
# Frame 86, Track 121: cx=927, cy=495
# Frame 86, Track 176: cx=931, cy=407
# Frame 86, Track 177: cx=998, cy=373
#
# 0: 640x384 35 players, 1 referee, 51.4ms
# Speed: 2.3ms preprocess, 51.4ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 384)
# Frame 87, Track 93: cx=1056, cy=198
# Frame 87, Track 121: cx=924, cy=497
# Frame 87, Track 176: cx=928, cy=408
# Frame 87, Track 177: cx=997, cy=371
#
# 0: 640x384 33 players, 1 referee, 51.4ms
# Speed: 1.7ms preprocess, 51.4ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 384)
# Frame 88, Track 93: cx=1053, cy=198
# Frame 88, Track 121: cx=921, cy=498
# Frame 88, Track 176: cx=923, cy=410
# Frame 88, Track 177: cx=994, cy=372
#
# 0: 640x384 39 players, 3 referees, 50.7ms
# Speed: 1.6ms preprocess, 50.7ms inference, 3.1ms postprocess per image at shape (1, 3, 640, 384)
# Frame 89, Track 93: cx=1053, cy=193
# Frame 89, Track 121: cx=919, cy=500
# Frame 89, Track 176: cx=919, cy=408
# Frame 89, Track 177: cx=991, cy=374
#
# 0: 640x384 35 players, 1 referee, 50.7ms
# Speed: 1.7ms preprocess, 50.7ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 384)
# Frame 90, Track 93: cx=1050, cy=193
# Frame 90, Track 121: cx=916, cy=502
# Frame 90, Track 176: cx=914, cy=405
# Frame 90, Track 177: cx=988, cy=375
#
# 0: 640x384 32 players, 1 referee, 50.9ms
# Speed: 1.6ms preprocess, 50.9ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 384)
# Frame 91, Track 93: cx=1047, cy=193
# Frame 91, Track 121: cx=913, cy=503
# Frame 91, Track 176: cx=907, cy=404
# Frame 91, Track 177: cx=986, cy=376
#
# 0: 640x384 33 players, 2 referees, 50.7ms
# Speed: 1.7ms preprocess, 50.7ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
# Frame 92, Track 93: cx=1035, cy=198
# Frame 92, Track 121: cx=910, cy=505
# Frame 92, Track 176: cx=900, cy=405
# Frame 92, Track 177: cx=979, cy=372
#
# 0: 640x384 34 players, 2 referees, 50.7ms
# Speed: 1.8ms preprocess, 50.7ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
# Frame 93, Track 93: cx=1029, cy=198
# Frame 93, Track 121: cx=907, cy=507
# Frame 93, Track 176: cx=893, cy=406
# Frame 93, Track 177: cx=975, cy=373
#
# 0: 640x384 32 players, 2 referees, 50.7ms
# Speed: 1.7ms preprocess, 50.7ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
# Frame 94, Track 93: cx=1022, cy=196
# Frame 94, Track 121: cx=904, cy=508
# Frame 94, Track 176: cx=888, cy=406
# Frame 94, Track 177: cx=972, cy=374
#
# 0: 640x384 33 players, 4 referees, 52.3ms
# Speed: 1.8ms preprocess, 52.3ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 384)
# Frame 95, Track 93: cx=1015, cy=195
# Frame 95, Track 121: cx=901, cy=510
# Frame 95, Track 176: cx=883, cy=405
# Frame 95, Track 177: cx=969, cy=375
#
# 0: 640x384 32 players, 4 referees, 52.2ms
# Speed: 2.7ms preprocess, 52.2ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
# Frame 96, Track 93: cx=1010, cy=195
# Frame 96, Track 121: cx=899, cy=512
# Frame 96, Track 176: cx=878, cy=405
# Frame 96, Track 177: cx=966, cy=376
#
# 0: 640x384 33 players, 3 referees, 52.2ms
# Speed: 3.1ms preprocess, 52.2ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
# Frame 97, Track 93: cx=1005, cy=195
# Frame 97, Track 121: cx=896, cy=513
# Frame 97, Track 176: cx=873, cy=404
# Frame 97, Track 177: cx=962, cy=377
#
# 0: 640x384 33 players, 4 referees, 52.2ms
# Speed: 1.7ms preprocess, 52.2ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
# Frame 98, Track 93: cx=1001, cy=195
# Frame 98, Track 121: cx=893, cy=515
# Frame 98, Track 176: cx=854, cy=395
# Frame 98, Track 177: cx=959, cy=377
#
# 0: 640x384 34 players, 4 referees, 51.4ms
# Speed: 1.7ms preprocess, 51.4ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
# Frame 99, Track 93: cx=996, cy=195
# Frame 99, Track 121: cx=890, cy=517
# Frame 99, Track 176: cx=848, cy=394
# Frame 99, Track 177: cx=956, cy=378
#
# 0: 640x384 38 players, 3 referees, 51.4ms
# Speed: 1.8ms preprocess, 51.4ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
# Frame 100, Track 93: cx=992, cy=194
# Frame 100, Track 121: cx=887, cy=518
# Frame 100, Track 176: cx=842, cy=392
# Frame 100, Track 177: cx=946, cy=415
#
# 0: 640x384 38 players, 1 referee, 51.5ms
# Speed: 1.5ms preprocess, 51.5ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
# Frame 101, Track 93: cx=983, cy=192
# Frame 101, Track 121: cx=885, cy=520
# Frame 101, Track 176: cx=836, cy=389
# Frame 101, Track 177: cx=943, cy=419
#
# 0: 640x384 34 players, 3 referees, 51.4ms
# Speed: 1.9ms preprocess, 51.4ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
# Frame 102, Track 93: cx=976, cy=192
# Frame 102, Track 121: cx=882, cy=522
# Frame 102, Track 176: cx=828, cy=385
# Frame 102, Track 177: cx=939, cy=423
#
# 0: 640x384 32 players, 3 referees, 51.4ms
# Speed: 1.7ms preprocess, 51.4ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 384)
# Frame 103, Track 93: cx=970, cy=192
# Frame 103, Track 121: cx=812, cy=417
# Frame 103, Track 176: cx=822, cy=383
# Frame 103, Track 177: cx=935, cy=426
#
# 0: 640x384 37 players, 2 referees, 51.4ms
# Speed: 1.8ms preprocess, 51.4ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 384)
# Frame 104, Track 93: cx=963, cy=192
# Frame 104, Track 121: cx=807, cy=416
# Frame 104, Track 176: cx=812, cy=386
# Frame 104, Track 177: cx=931, cy=430
#
# 0: 640x384 41 players, 3 referees, 51.5ms
# Speed: 1.7ms preprocess, 51.5ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 384)
# Frame 105, Track 93: cx=958, cy=192
# Frame 105, Track 121: cx=803, cy=415
# Frame 105, Track 176: cx=804, cy=381
# Frame 105, Track 177: cx=928, cy=434
#
# 0: 640x384 33 players, 1 referee, 54.8ms
# Speed: 1.8ms preprocess, 54.8ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
# Frame 106, Track 93: cx=952, cy=191
# Frame 106, Track 121: cx=798, cy=414
# Frame 106, Track 176: cx=797, cy=381
# Frame 106, Track 177: cx=924, cy=438
#
# 0: 640x384 2 balls, 35 players, 2 referees, 54.0ms
# Speed: 1.9ms preprocess, 54.0ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
# Frame 107, Track 93: cx=947, cy=191
# Frame 107, Track 121: cx=794, cy=413
# Frame 107, Track 176: cx=787, cy=377
# Frame 107, Track 177: cx=921, cy=441
#
# 0: 640x384 2 balls, 33 players, 2 referees, 53.8ms
# Speed: 1.6ms preprocess, 53.8ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
# Frame 108, Track 93: cx=941, cy=191
# Frame 108, Track 121: cx=789, cy=412
# Frame 108, Track 176: cx=779, cy=371
# Frame 108, Track 177: cx=917, cy=445
#
# 0: 640x384 1 ball, 36 players, 3 referees, 52.3ms
# Speed: 1.8ms preprocess, 52.3ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 384)
# Frame 109, Track 93: cx=936, cy=191
# Frame 109, Track 121: cx=785, cy=411
# Frame 109, Track 176: cx=772, cy=369
# Frame 109, Track 177: cx=913, cy=449
#
# 0: 640x384 3 balls, 39 players, 2 referees, 52.2ms
# Speed: 2.0ms preprocess, 52.2ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
# Frame 110, Track 93: cx=930, cy=191
# Frame 110, Track 121: cx=780, cy=410
# Frame 110, Track 176: cx=764, cy=373
# Frame 110, Track 177: cx=909, cy=452
#
# 0: 640x384 1 ball, 35 players, 1 referee, 52.2ms
# Speed: 1.8ms preprocess, 52.2ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
# Frame 111, Track 93: cx=924, cy=190
# Frame 111, Track 121: cx=776, cy=409
# Frame 111, Track 176: cx=757, cy=371
# Frame 111, Track 177: cx=905, cy=456
#
# 0: 640x384 1 ball, 32 players, 2 referees, 52.2ms
# Speed: 2.2ms preprocess, 52.2ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
# Frame 112, Track 93: cx=919, cy=190
# Frame 112, Track 121: cx=771, cy=408
# Frame 112, Track 176: cx=749, cy=370
# Frame 112, Track 177: cx=902, cy=460
#
# 0: 640x384 32 players, 1 referee, 51.4ms
# Speed: 1.7ms preprocess, 51.4ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
# Frame 113, Track 93: cx=914, cy=190
# Frame 113, Track 121: cx=767, cy=407
# Frame 113, Track 176: cx=747, cy=364
# Frame 113, Track 177: cx=898, cy=463
#
# 0: 640x384 28 players, 3 referees, 51.5ms
# Speed: 2.2ms preprocess, 51.5ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
# Frame 114, Track 93: cx=908, cy=190
# Frame 114, Track 121: cx=762, cy=406
# Frame 114, Track 176: cx=739, cy=362
# Frame 114, Track 177: cx=894, cy=467
#
# 0: 640x384 1 ball, 36 players, 2 referees, 51.4ms
# Speed: 1.7ms preprocess, 51.4ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
# Frame 115, Track 93: cx=903, cy=190
# Frame 115, Track 121: cx=758, cy=405
# Frame 115, Track 176: cx=733, cy=359
# Frame 115, Track 177: cx=890, cy=471
#
# 0: 640x384 1 ball, 37 players, 2 referees, 51.4ms
# Speed: 1.8ms preprocess, 51.4ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
# Frame 116, Track 93: cx=897, cy=189
# Frame 116, Track 121: cx=753, cy=404
# Frame 116, Track 176: cx=726, cy=357
# Frame 116, Track 177: cx=887, cy=474
#
# 0: 640x384 40 players, 1 referee, 51.5ms
# Speed: 2.1ms preprocess, 51.5ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 384)
# Frame 117, Track 93: cx=881, cy=194
# Frame 117, Track 121: cx=749, cy=403
# Frame 117, Track 176: cx=719, cy=355
# Frame 117, Track 177: cx=883, cy=478
#
# 0: 640x384 27 players, 2 referees, 51.5ms
# Speed: 1.7ms preprocess, 51.5ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 384)
# Frame 118, Track 93: cx=875, cy=196
# Frame 118, Track 121: cx=744, cy=402
# Frame 118, Track 176: cx=713, cy=353
# Frame 118, Track 177: cx=879, cy=481
#
# 0: 640x384 1 ball, 34 players, 2 referees, 56.0ms
# Speed: 1.8ms preprocess, 56.0ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 384)
# Frame 119, Track 93: cx=868, cy=192
# Frame 119, Track 121: cx=739, cy=401
# Frame 119, Track 176: cx=706, cy=351
# Frame 119, Track 177: cx=875, cy=485
#
# 0: 640x384 1 ball, 27 players, 1 referee, 57.6ms
# Speed: 1.8ms preprocess, 57.6ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 384)
# Frame 120, Track 93: cx=862, cy=192
# Frame 120, Track 121: cx=735, cy=400
# Frame 120, Track 176: cx=699, cy=349
# Frame 120, Track 177: cx=871, cy=489
#
# 0: 640x384 24 players, 1 referee, 60.9ms
# Speed: 1.9ms preprocess, 60.9ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 384)
# Frame 121, Track 93: cx=856, cy=192
# Frame 121, Track 121: cx=731, cy=399
# Frame 121, Track 176: cx=692, cy=347
# Frame 121, Track 177: cx=868, cy=492
#
# 0: 640x384 27 players, 3 referees, 63.4ms
# Speed: 1.8ms preprocess, 63.4ms inference, 2.8ms postprocess per image at shape (1, 3, 640, 384)
# Frame 122, Track 93: cx=850, cy=192
# Frame 122, Track 121: cx=726, cy=398
# Frame 122, Track 176: cx=685, cy=345
# Frame 122, Track 177: cx=864, cy=496
#
# 0: 640x384 28 players, 2 referees, 67.5ms
# Speed: 2.0ms preprocess, 67.5ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 384)
# Frame 123, Track 93: cx=843, cy=193
# Frame 123, Track 121: cx=722, cy=397
# Frame 123, Track 176: cx=681, cy=354
# Frame 123, Track 177: cx=860, cy=500
#
# 0: 640x384 24 players, 4 referees, 56.5ms
# Speed: 2.2ms preprocess, 56.5ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
# Frame 124, Track 93: cx=830, cy=195
# Frame 124, Track 121: cx=717, cy=396
# Frame 124, Track 176: cx=674, cy=353
# Frame 124, Track 177: cx=856, cy=503
#
# 0: 640x384 23 players, 4 referees, 53.8ms
# Speed: 1.8ms preprocess, 53.8ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
# Frame 125, Track 93: cx=822, cy=196
# Frame 125, Track 121: cx=713, cy=395
# Frame 125, Track 176: cx=668, cy=352
# Frame 125, Track 177: cx=853, cy=507
#
# 0: 640x384 25 players, 4 referees, 53.1ms
# Speed: 2.0ms preprocess, 53.1ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
# Frame 126, Track 93: cx=814, cy=194
# Frame 126, Track 121: cx=708, cy=394
# Frame 126, Track 176: cx=661, cy=351
# Frame 126, Track 177: cx=849, cy=511
#
# 0: 640x384 29 players, 2 referees, 53.0ms
# Speed: 1.9ms preprocess, 53.0ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
# Frame 127, Track 93: cx=810, cy=192
# Frame 127, Track 121: cx=704, cy=393
# Frame 127, Track 176: cx=655, cy=350
# Frame 127, Track 177: cx=845, cy=515
#
# 0: 640x384 32 players, 2 referees, 54.1ms
# Speed: 1.6ms preprocess, 54.1ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
# Frame 128, Track 93: cx=803, cy=192
# Frame 128, Track 121: cx=699, cy=392
# Frame 128, Track 176: cx=648, cy=349
# Frame 128, Track 177: cx=842, cy=518
#
# 0: 640x384 1 ball, 30 players, 2 referees, 53.0ms
# Speed: 1.7ms preprocess, 53.0ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
# Frame 129, Track 93: cx=808, cy=193
# Frame 129, Track 121: cx=694, cy=391
# Frame 129, Track 176: cx=641, cy=348
# Frame 129, Track 177: cx=838, cy=522
#
# 0: 640x384 31 players, 2 referees, 53.1ms
# Speed: 2.2ms preprocess, 53.1ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
# Frame 130, Track 93: cx=802, cy=193
# Frame 130, Track 121: cx=727, cy=371
# Frame 130, Track 176: cx=635, cy=346
# Frame 130, Track 177: cx=834, cy=526
#
# 0: 640x384 1 ball, 23 players, 1 referee, 52.3ms
# Speed: 1.9ms preprocess, 52.3ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
# Frame 131, Track 93: cx=797, cy=193
# Frame 131, Track 121: cx=725, cy=369
# Frame 131, Track 176: cx=628, cy=346
# Frame 131, Track 177: cx=830, cy=529
#
# 0: 640x384 25 players, 1 referee, 51.5ms
# Speed: 1.8ms preprocess, 51.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
# Frame 132, Track 93: cx=796, cy=196
# Frame 132, Track 121: cx=722, cy=367
# Frame 132, Track 176: cx=621, cy=344
# Frame 132, Track 177: cx=827, cy=533
#
# 0: 640x384 25 players, 1 referee, 51.4ms
# Speed: 1.9ms preprocess, 51.4ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
# Frame 133, Track 93: cx=791, cy=196
# Frame 133, Track 121: cx=719, cy=365
# Frame 133, Track 176: cx=615, cy=343
# Frame 133, Track 177: cx=823, cy=537
#
# 0: 640x384 1 ball, 25 players, 1 referee, 51.5ms
# Speed: 2.1ms preprocess, 51.5ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
# Frame 134, Track 93: cx=787, cy=194
# Frame 134, Track 121: cx=716, cy=363
# Frame 134, Track 176: cx=608, cy=342
# Frame 134, Track 177: cx=819, cy=540
#
# 0: 640x384 28 players, 2 referees, 51.4ms
# Speed: 1.4ms preprocess, 51.4ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
# Frame 135, Track 93: cx=782, cy=195
# Frame 135, Track 121: cx=713, cy=362
# Frame 135, Track 176: cx=601, cy=341
# Frame 135, Track 177: cx=815, cy=544
# Frame 135, Track 352: cx=1115, cy=278
#
# 0: 640x384 32 players, 2 referees, 51.5ms
# Speed: 1.6ms preprocess, 51.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
# Frame 136, Track 93: cx=777, cy=195
# Frame 136, Track 121: cx=710, cy=360
# Frame 136, Track 176: cx=595, cy=340
# Frame 136, Track 177: cx=811, cy=548
# Frame 136, Track 352: cx=1112, cy=279
#
# 0: 640x384 27 players, 1 referee, 51.4ms
# Speed: 1.8ms preprocess, 51.4ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
# Frame 137, Track 93: cx=777, cy=194
# Frame 137, Track 121: cx=708, cy=358
# Frame 137, Track 176: cx=588, cy=339
# Frame 137, Track 177: cx=808, cy=551
# Frame 137, Track 352: cx=1100, cy=278
#
# 0: 640x384 27 players, 2 referees, 51.4ms
# Speed: 1.4ms preprocess, 51.4ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
# Frame 138, Track 93: cx=772, cy=194
# Frame 138, Track 121: cx=705, cy=356
# Frame 138, Track 176: cx=581, cy=338
# Frame 138, Track 177: cx=804, cy=555
# Frame 138, Track 352: cx=1095, cy=279
#
# 0: 640x384 36 players, 2 referees, 54.8ms
# Speed: 1.7ms preprocess, 54.8ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
# Frame 139, Track 93: cx=770, cy=198
# Frame 139, Track 121: cx=702, cy=355
# Frame 139, Track 176: cx=574, cy=337
# Frame 139, Track 177: cx=800, cy=559
# Frame 139, Track 352: cx=1078, cy=276
#
# 0: 640x384 30 players, 2 referees, 56.3ms
# Speed: 1.8ms preprocess, 56.3ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 384)
# Frame 140, Track 93: cx=765, cy=198
# Frame 140, Track 121: cx=699, cy=353
# Frame 140, Track 176: cx=568, cy=336
# Frame 140, Track 177: cx=796, cy=562
# Frame 140, Track 352: cx=1065, cy=275
#
# 0: 640x384 31 players, 1 referee, 54.8ms
# Speed: 1.8ms preprocess, 54.8ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
# Frame 141, Track 93: cx=758, cy=196
# Frame 141, Track 121: cx=696, cy=351
# Frame 141, Track 176: cx=561, cy=335
# Frame 141, Track 177: cx=793, cy=566
# Frame 141, Track 352: cx=1057, cy=275
#
# 0: 640x384 29 players, 2 referees, 54.7ms
# Speed: 1.9ms preprocess, 54.7ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
# Frame 142, Track 93: cx=750, cy=195
# Frame 142, Track 121: cx=693, cy=349
# Frame 142, Track 176: cx=554, cy=334
# Frame 142, Track 177: cx=789, cy=570
# Frame 142, Track 352: cx=1049, cy=275
#
# 0: 640x384 25 players, 2 referees, 53.8ms
# Speed: 1.3ms preprocess, 53.8ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 384)
# Frame 143, Track 93: cx=746, cy=195
# Frame 143, Track 121: cx=690, cy=347
# Frame 143, Track 176: cx=548, cy=333
# Frame 143, Track 177: cx=785, cy=574
# Frame 143, Track 352: cx=1041, cy=275
#
# 0: 640x384 25 players, 2 referees, 53.8ms
# Speed: 1.8ms preprocess, 53.8ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 384)
# Frame 144, Track 93: cx=741, cy=195
# Frame 144, Track 121: cx=687, cy=345
# Frame 144, Track 176: cx=541, cy=332
# Frame 144, Track 177: cx=781, cy=577
# Frame 144, Track 352: cx=1033, cy=274
#
# 0: 640x384 31 players, 2 referees, 53.9ms
# Speed: 1.8ms preprocess, 53.9ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
# Frame 145, Track 93: cx=736, cy=196
# Frame 145, Track 121: cx=649, cy=319
# Frame 145, Track 176: cx=534, cy=331
# Frame 145, Track 177: cx=777, cy=581
# Frame 145, Track 352: cx=1025, cy=274
#
# 0: 640x384 27 players, 1 referee, 54.1ms
# Speed: 2.0ms preprocess, 54.1ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
# Frame 146, Track 93: cx=731, cy=196
# Frame 146, Track 121: cx=642, cy=317
# Frame 146, Track 176: cx=528, cy=329
# Frame 146, Track 177: cx=774, cy=585
# Frame 146, Track 352: cx=1017, cy=274
#
# 0: 640x384 27 players, 1 referee, 53.9ms
# Speed: 1.9ms preprocess, 53.9ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 384)
# Frame 147, Track 93: cx=726, cy=196
# Frame 147, Track 121: cx=640, cy=316
# Frame 147, Track 176: cx=521, cy=328
# Frame 147, Track 177: cx=770, cy=588
# Frame 147, Track 352: cx=1009, cy=274
#
# 0: 640x384 2 balls, 33 players, 2 referees, 53.9ms
# Speed: 1.8ms preprocess, 53.9ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
# Frame 148, Track 93: cx=721, cy=196
# Frame 148, Track 121: cx=640, cy=315
# Frame 148, Track 176: cx=514, cy=327
# Frame 148, Track 177: cx=767, cy=592
# Frame 148, Track 352: cx=1001, cy=274
# Frame 148, Track 372: cx=1210, cy=305
#
# 0: 640x384 35 players, 3 referees, 53.0ms
# Speed: 2.5ms preprocess, 53.0ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
# Frame 149, Track 93: cx=719, cy=201
# Frame 149, Track 121: cx=641, cy=314
# Frame 149, Track 176: cx=508, cy=326
# Frame 149, Track 177: cx=763, cy=596
# Frame 149, Track 352: cx=994, cy=274
# Frame 149, Track 372: cx=1206, cy=305
#
# 0: 640x384 29 players, 3 referees, 53.1ms
# Speed: 2.1ms preprocess, 53.1ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
# Frame 150, Track 93: cx=716, cy=200
# Frame 150, Track 121: cx=641, cy=313
# Frame 150, Track 176: cx=502, cy=325
# Frame 150, Track 177: cx=759, cy=599
# Frame 150, Track 352: cx=986, cy=274
# Frame 150, Track 372: cx=1205, cy=306
#
# 0: 640x384 24 players, 2 referees, 53.0ms
# Speed: 1.4ms preprocess, 53.0ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
# Frame 151, Track 93: cx=711, cy=201
# Frame 151, Track 121: cx=643, cy=312
# Frame 151, Track 176: cx=396, cy=391
# Frame 151, Track 177: cx=859, cy=371
# Frame 151, Track 352: cx=978, cy=274
# Frame 151, Track 372: cx=1202, cy=306
#
# 0: 640x384 29 players, 2 referees, 53.0ms
# Speed: 2.8ms preprocess, 53.0ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
# Frame 152, Track 93: cx=707, cy=201
# Frame 152, Track 121: cx=641, cy=310
# Frame 152, Track 176: cx=392, cy=393
# Frame 152, Track 177: cx=858, cy=370
# Frame 152, Track 352: cx=970, cy=274
# Frame 152, Track 372: cx=1199, cy=306
#
# 0: 640x384 33 players, 2 referees, 54.4ms
# Speed: 2.5ms preprocess, 54.4ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 384)
# Frame 153, Track 93: cx=702, cy=202
# Frame 153, Track 121: cx=638, cy=308
# Frame 153, Track 176: cx=388, cy=393
# Frame 153, Track 177: cx=862, cy=367
# Frame 153, Track 352: cx=962, cy=273
# Frame 153, Track 372: cx=1199, cy=305
#
# 0: 640x384 31 players, 1 referee, 56.6ms
# Speed: 1.8ms preprocess, 56.6ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
# Frame 154, Track 93: cx=698, cy=202
# Frame 154, Track 121: cx=636, cy=306
# Frame 154, Track 176: cx=386, cy=393
# Frame 154, Track 177: cx=866, cy=367
# Frame 154, Track 352: cx=954, cy=273
# Frame 154, Track 372: cx=1199, cy=304
#
# 0: 640x384 37 players, 1 referee, 59.1ms
# Speed: 1.8ms preprocess, 59.1ms inference, 2.9ms postprocess per image at shape (1, 3, 640, 384)
# Frame 155, Track 93: cx=706, cy=208
# Frame 155, Track 121: cx=634, cy=304
# Frame 155, Track 176: cx=383, cy=392
# Frame 155, Track 177: cx=865, cy=365
# Frame 155, Track 352: cx=946, cy=273
# Frame 155, Track 372: cx=1199, cy=305
#
# 0: 640x384 35 players, 1 referee, 64.6ms
# Speed: 1.8ms preprocess, 64.6ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 384)
# Frame 156, Track 93: cx=705, cy=210
# Frame 156, Track 121: cx=632, cy=302
# Frame 156, Track 176: cx=381, cy=392
# Frame 156, Track 177: cx=865, cy=364
# Frame 156, Track 352: cx=938, cy=273
# Frame 156, Track 372: cx=1197, cy=305
#
# 0: 640x384 34 players, 2 referees, 61.0ms
# Speed: 2.2ms preprocess, 61.0ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 384)
# Frame 157, Track 93: cx=704, cy=210
# Frame 157, Track 121: cx=629, cy=300
# Frame 157, Track 176: cx=376, cy=392
# Frame 157, Track 177: cx=864, cy=362
# Frame 157, Track 352: cx=930, cy=273
# Frame 157, Track 372: cx=1202, cy=307
#
# 0: 640x384 31 players, 3 referees, 60.9ms
# Speed: 1.8ms preprocess, 60.9ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 384)
# Frame 158, Track 93: cx=701, cy=206
# Frame 158, Track 121: cx=627, cy=298
# Frame 158, Track 176: cx=371, cy=392
# Frame 158, Track 177: cx=863, cy=361
# Frame 158, Track 352: cx=922, cy=273
# Frame 158, Track 372: cx=1200, cy=307
#
# 0: 640x384 28 players, 2 referees, 61.0ms
# Speed: 1.9ms preprocess, 61.0ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 384)
# Frame 159, Track 93: cx=698, cy=207
# Frame 159, Track 121: cx=625, cy=296
# Frame 159, Track 176: cx=366, cy=393
# Frame 159, Track 177: cx=863, cy=359
# Frame 159, Track 352: cx=915, cy=273
# Frame 159, Track 372: cx=1202, cy=307
#
# 0: 640x384 31 players, 2 referees, 64.7ms
# Speed: 2.0ms preprocess, 64.7ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
# Frame 160, Track 93: cx=695, cy=208
# Frame 160, Track 121: cx=623, cy=294
# Frame 160, Track 176: cx=361, cy=393
# Frame 160, Track 177: cx=862, cy=358
# Frame 160, Track 352: cx=906, cy=273
# Frame 160, Track 372: cx=1199, cy=307
#
# 0: 640x384 35 players, 3 referees, 56.5ms
# Speed: 1.5ms preprocess, 56.5ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
# Frame 161, Track 93: cx=692, cy=208
# Frame 161, Track 121: cx=621, cy=292
# Frame 161, Track 176: cx=361, cy=390
# Frame 161, Track 177: cx=861, cy=356
# Frame 161, Track 352: cx=785, cy=285
# Frame 161, Track 372: cx=1198, cy=307
#
# 0: 640x384 27 players, 1 referee, 54.7ms
# Speed: 1.7ms preprocess, 54.7ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
# Frame 162, Track 93: cx=689, cy=208
# Frame 162, Track 121: cx=618, cy=290
# Frame 162, Track 176: cx=358, cy=390
# Frame 162, Track 177: cx=860, cy=355
# Frame 162, Track 352: cx=772, cy=286
# Frame 162, Track 372: cx=1197, cy=308
#
# 0: 640x384 35 players, 2 referees, 53.9ms
# Speed: 1.8ms preprocess, 53.9ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 384)
# Frame 163, Track 93: cx=686, cy=209
# Frame 163, Track 121: cx=616, cy=288
# Frame 163, Track 176: cx=353, cy=392
# Frame 163, Track 177: cx=860, cy=353
# Frame 163, Track 352: cx=762, cy=288
# Frame 163, Track 372: cx=1195, cy=308
#
# 0: 640x384 33 players, 1 referee, 53.9ms
# Speed: 1.5ms preprocess, 53.9ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
# Frame 164, Track 93: cx=683, cy=209
# Frame 164, Track 121: cx=614, cy=285
# Frame 164, Track 176: cx=348, cy=393
# Frame 164, Track 177: cx=859, cy=352
# Frame 164, Track 352: cx=749, cy=289
# Frame 164, Track 372: cx=1191, cy=301
#
# 0: 640x384 37 players, 1 referee, 52.2ms
# Speed: 1.8ms preprocess, 52.2ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 384)
# Frame 165, Track 93: cx=685, cy=210
# Frame 165, Track 121: cx=612, cy=283
# Frame 165, Track 176: cx=344, cy=394
# Frame 165, Track 177: cx=858, cy=351
# Frame 165, Track 352: cx=737, cy=290
# Frame 165, Track 372: cx=1189, cy=301
#
# 0: 640x384 32 players, 1 referee, 52.2ms
# Speed: 1.9ms preprocess, 52.2ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
# Frame 166, Track 93: cx=682, cy=210
# Frame 166, Track 121: cx=609, cy=281
# Frame 166, Track 176: cx=340, cy=394
# Frame 166, Track 177: cx=858, cy=349
# Frame 166, Track 352: cx=724, cy=290
# Frame 166, Track 372: cx=1187, cy=293
#
# 0: 640x384 25 players, 2 referees, 52.3ms
# Speed: 2.2ms preprocess, 52.3ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 384)
# Frame 167, Track 93: cx=680, cy=211
# Frame 167, Track 121: cx=607, cy=279
# Frame 167, Track 176: cx=335, cy=395
# Frame 167, Track 177: cx=857, cy=348
# Frame 167, Track 352: cx=711, cy=291
# Frame 167, Track 372: cx=1183, cy=291
#
# 0: 640x384 29 players, 2 referees, 52.3ms
# Speed: 2.0ms preprocess, 52.3ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
# Frame 168, Track 93: cx=677, cy=211
# Frame 168, Track 121: cx=605, cy=277
# Frame 168, Track 176: cx=331, cy=395
# Frame 168, Track 177: cx=856, cy=346
# Frame 168, Track 352: cx=698, cy=292
# Frame 168, Track 372: cx=1181, cy=290
#
# 0: 640x384 28 players, 2 referees, 52.2ms
# Speed: 1.7ms preprocess, 52.2ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
# Frame 169, Track 93: cx=675, cy=212
# Frame 169, Track 121: cx=602, cy=275
# Frame 169, Track 176: cx=327, cy=395
# Frame 169, Track 177: cx=906, cy=352
# Frame 169, Track 352: cx=685, cy=293
# Frame 169, Track 372: cx=1179, cy=288
#
# 0: 640x384 26 players, 2 referees, 54.8ms
# Speed: 1.6ms preprocess, 54.8ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 384)
# Frame 170, Track 93: cx=673, cy=213
# Frame 170, Track 121: cx=600, cy=273
# Frame 170, Track 176: cx=322, cy=395
# Frame 170, Track 177: cx=910, cy=353
# Frame 170, Track 352: cx=672, cy=293
# Frame 170, Track 372: cx=1177, cy=287
#
# 0: 640x384 31 players, 1 referee, 53.9ms
# Speed: 1.9ms preprocess, 53.9ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 384)
# Frame 171, Track 93: cx=670, cy=213
# Frame 171, Track 121: cx=598, cy=271
# Frame 171, Track 176: cx=318, cy=396
# Frame 171, Track 177: cx=912, cy=353
# Frame 171, Track 352: cx=659, cy=294
# Frame 171, Track 372: cx=1175, cy=286
#
# 0: 640x384 32 players, 1 referee, 53.8ms
# Speed: 1.3ms preprocess, 53.8ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
# Frame 172, Track 93: cx=667, cy=214
# Frame 172, Track 121: cx=596, cy=269
# Frame 172, Track 176: cx=313, cy=396
# Frame 172, Track 177: cx=914, cy=352
# Frame 172, Track 352: cx=647, cy=295
# Frame 172, Track 372: cx=1173, cy=284
# Frame 172, Track 442: cx=1171, cy=302
#
# 0: 640x384 29 players, 2 referees, 53.8ms
# Speed: 1.7ms preprocess, 53.8ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 384)
# Frame 173, Track 93: cx=665, cy=214
# Frame 173, Track 121: cx=593, cy=267
# Frame 173, Track 176: cx=309, cy=396
# Frame 173, Track 177: cx=916, cy=351
# Frame 173, Track 352: cx=634, cy=296
# Frame 173, Track 372: cx=1171, cy=283
# Frame 173, Track 442: cx=1171, cy=300
#
# 0: 640x384 1 ball, 27 players, 1 referee, 53.9ms
# Speed: 1.4ms preprocess, 53.9ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
# Frame 174, Track 93: cx=662, cy=215
# Frame 174, Track 121: cx=591, cy=265
# Frame 174, Track 176: cx=304, cy=397
# Frame 174, Track 177: cx=919, cy=350
# Frame 174, Track 352: cx=621, cy=297
# Frame 174, Track 372: cx=1169, cy=281
# Frame 174, Track 442: cx=1170, cy=298
#
# 0: 640x384 29 players, 56.6ms
# Speed: 1.6ms preprocess, 56.6ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
# Frame 175, Track 93: cx=659, cy=215
# Frame 175, Track 121: cx=589, cy=263
# Frame 175, Track 176: cx=300, cy=397
# Frame 175, Track 177: cx=921, cy=350
# Frame 175, Track 352: cx=642, cy=278
# Frame 175, Track 372: cx=1167, cy=280
# Frame 175, Track 442: cx=1169, cy=298
#
# 0: 640x384 31 players, 1 referee, 54.7ms
# Speed: 1.7ms preprocess, 54.7ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 384)
# Frame 176, Track 93: cx=657, cy=216
# Frame 176, Track 121: cx=586, cy=261
# Frame 176, Track 176: cx=296, cy=398
# Frame 176, Track 177: cx=923, cy=349
# Frame 176, Track 352: cx=632, cy=279
# Frame 176, Track 372: cx=1165, cy=278
# Frame 176, Track 442: cx=1167, cy=297
#
# 0: 640x384 33 players, 54.8ms
# Speed: 1.7ms preprocess, 54.8ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
# Frame 177, Track 93: cx=655, cy=216
# Frame 177, Track 121: cx=584, cy=259
# Frame 177, Track 176: cx=291, cy=398
# Frame 177, Track 177: cx=926, cy=348
# Frame 177, Track 352: cx=624, cy=278
# Frame 177, Track 372: cx=1163, cy=277
# Frame 177, Track 442: cx=1165, cy=299
#
# 0: 640x384 29 players, 2 referees, 54.2ms
# Speed: 1.9ms preprocess, 54.2ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
# Frame 178, Track 93: cx=652, cy=217
# Frame 178, Track 121: cx=582, cy=257
# Frame 178, Track 176: cx=287, cy=398
# Frame 178, Track 177: cx=928, cy=348
# Frame 178, Track 352: cx=614, cy=277
# Frame 178, Track 372: cx=1160, cy=275
# Frame 178, Track 442: cx=1164, cy=299
#
# 0: 640x384 2 balls, 22 players, 1 referee, 53.9ms
# Speed: 2.4ms preprocess, 53.9ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 384)
# Frame 179, Track 93: cx=650, cy=217
# Frame 179, Track 121: cx=580, cy=255
# Frame 179, Track 176: cx=297, cy=393
# Frame 179, Track 177: cx=936, cy=349
# Frame 179, Track 352: cx=603, cy=277
# Frame 179, Track 372: cx=1163, cy=291
# Frame 179, Track 442: cx=1163, cy=299
#
# 0: 640x384 27 players, 53.9ms
# Speed: 3.1ms preprocess, 53.9ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 384)
# Frame 180, Track 93: cx=638, cy=210
# Frame 180, Track 121: cx=578, cy=253
# Frame 180, Track 176: cx=293, cy=393
# Frame 180, Track 177: cx=939, cy=350
# Frame 180, Track 352: cx=593, cy=276
# Frame 180, Track 372: cx=1161, cy=290
# Frame 180, Track 442: cx=1162, cy=298
#
# 0: 640x384 24 players, 2 referees, 53.9ms
# Speed: 1.6ms preprocess, 53.9ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
# Frame 181, Track 93: cx=634, cy=209
# Frame 181, Track 121: cx=489, cy=316
# Frame 181, Track 176: cx=290, cy=393
# Frame 181, Track 177: cx=939, cy=350
# Frame 181, Track 352: cx=583, cy=276
# Frame 181, Track 372: cx=1159, cy=289
# Frame 181, Track 442: cx=1161, cy=298
#
# 0: 640x384 27 players, 3 referees, 53.7ms
# Speed: 1.5ms preprocess, 53.7ms inference, 2.8ms postprocess per image at shape (1, 3, 640, 384)
# Frame 182, Track 93: cx=631, cy=209
# Frame 182, Track 121: cx=484, cy=315
# Frame 182, Track 176: cx=287, cy=394
# Frame 182, Track 177: cx=940, cy=347
# Frame 182, Track 352: cx=573, cy=275
# Frame 182, Track 372: cx=1157, cy=287
# Frame 182, Track 442: cx=1160, cy=297
#
# 0: 640x384 1 ball, 28 players, 2 referees, 53.1ms
# Speed: 2.6ms preprocess, 53.1ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
# Frame 183, Track 93: cx=629, cy=211
# Frame 183, Track 121: cx=480, cy=313
# Frame 183, Track 176: cx=283, cy=393
# Frame 183, Track 177: cx=942, cy=346
# Frame 183, Track 352: cx=583, cy=278
# Frame 183, Track 372: cx=1154, cy=286
# Frame 183, Track 442: cx=1159, cy=297
#
# 0: 640x384 28 players, 1 referee, 53.1ms
# Speed: 4.7ms preprocess, 53.1ms inference, 2.7ms postprocess per image at shape (1, 3, 640, 384)
# Frame 184, Track 93: cx=626, cy=211
# Frame 184, Track 121: cx=474, cy=313
# Frame 184, Track 176: cx=279, cy=393
# Frame 184, Track 177: cx=944, cy=350
# Frame 184, Track 352: cx=579, cy=278
# Frame 184, Track 372: cx=1153, cy=285
# Frame 184, Track 442: cx=1151, cy=295
#
# ...
# Frame 326, Track 121: cx=-132, cy=493
# Frame 326, Track 177: cx=556, cy=302
# Frame 326, Track 442: cx=-118, cy=204
# Frame 326, Track 623: cx=660, cy=306
# Frame 326, Track 673: cx=449, cy=267
# Frame 326, Track 700: cx=531, cy=271
#
# 0: 640x384 2 goalkeepers, 21 players, 57.6ms
# Speed: 1.6ms preprocess, 57.6ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
# Frame 327, Track 121: cx=-136, cy=496
# Frame 327, Track 177: cx=556, cy=301
# Frame 327, Track 442: cx=-130, cy=202
# Frame 327, Track 623: cx=658, cy=305
# Frame 327, Track 673: cx=449, cy=268
# Frame 327, Track 700: cx=532, cy=271
#
# 0: 640x384 1 goalkeeper, 22 players, 57.6ms
# Speed: 1.6ms preprocess, 57.6ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
# Frame 328, Track 121: cx=-140, cy=500
# Frame 328, Track 177: cx=555, cy=300
# Frame 328, Track 442: cx=-141, cy=201
# Frame 328, Track 623: cx=657, cy=304
# Frame 328, Track 673: cx=449, cy=268
# Frame 328, Track 700: cx=532, cy=270
#
# 0: 640x384 1 ball, 2 goalkeepers, 21 players, 56.6ms
# Speed: 1.8ms preprocess, 56.6ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
# Frame 329, Track 121: cx=-144, cy=504
# Frame 329, Track 177: cx=554, cy=300
# Frame 329, Track 442: cx=-152, cy=199
# Frame 329, Track 623: cx=655, cy=303
# Frame 329, Track 673: cx=449, cy=269
# Frame 329, Track 700: cx=532, cy=269
#
# 0: 640x384 3 goalkeepers, 20 players, 56.6ms
# Speed: 1.8ms preprocess, 56.6ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 384)
# Frame 330, Track 121: cx=-148, cy=507
# Frame 330, Track 177: cx=554, cy=299
# Frame 330, Track 442: cx=-164, cy=197
# Frame 330, Track 623: cx=652, cy=302
# Frame 330, Track 673: cx=449, cy=270
# Frame 330, Track 700: cx=533, cy=268
#
# 0: 640x384 2 goalkeepers, 24 players, 56.7ms
# Speed: 1.9ms preprocess, 56.7ms inference, 3.1ms postprocess per image at shape (1, 3, 640, 384)
# Frame 331, Track 121: cx=-152, cy=511
# Frame 331, Track 177: cx=553, cy=298
# Frame 331, Track 442: cx=-175, cy=195
# Frame 331, Track 623: cx=650, cy=300
# Frame 331, Track 673: cx=395, cy=324
# Frame 331, Track 700: cx=534, cy=268
#
# 0: 640x384 1 goalkeeper, 21 players, 56.7ms
# Speed: 1.8ms preprocess, 56.7ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
# Frame 332, Track 121: cx=-156, cy=515
# Frame 332, Track 177: cx=553, cy=297
# Frame 332, Track 442: cx=-187, cy=194
# Frame 332, Track 623: cx=649, cy=299
# Frame 332, Track 673: cx=379, cy=327
# Frame 332, Track 700: cx=534, cy=267
#
# 0: 640x384 2 goalkeepers, 25 players, 58.7ms
# Speed: 2.0ms preprocess, 58.7ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
# Frame 333, Track 121: cx=-160, cy=519
# Frame 333, Track 177: cx=552, cy=296
# Frame 333, Track 442: cx=-198, cy=192
# Frame 333, Track 623: cx=657, cy=297
# Frame 333, Track 673: cx=375, cy=330
# Frame 333, Track 700: cx=535, cy=267
#
# 0: 640x384 2 goalkeepers, 23 players, 57.6ms
# Speed: 3.3ms preprocess, 57.6ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
# Frame 334, Track 121: cx=-164, cy=523
# Frame 334, Track 177: cx=552, cy=295
# Frame 334, Track 442: cx=-210, cy=190
# Frame 334, Track 623: cx=649, cy=296
# Frame 334, Track 673: cx=371, cy=333
# Frame 334, Track 700: cx=536, cy=266
#
# 0: 640x384 2 goalkeepers, 24 players, 56.7ms
# Speed: 2.1ms preprocess, 56.7ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
# Frame 335, Track 121: cx=-168, cy=526
# Frame 335, Track 177: cx=551, cy=295
# Frame 335, Track 442: cx=-221, cy=188
# Frame 335, Track 623: cx=640, cy=293
# Frame 335, Track 673: cx=367, cy=336
# Frame 335, Track 700: cx=536, cy=265
#
# 0: 640x384 1 goalkeeper, 27 players, 56.6ms
# Speed: 1.6ms preprocess, 56.6ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 384)
# Frame 336, Track 121: cx=-172, cy=530
# Frame 336, Track 177: cx=551, cy=294
# Frame 336, Track 442: cx=-233, cy=186
# Frame 336, Track 623: cx=637, cy=292
# Frame 336, Track 673: cx=363, cy=339
# Frame 336, Track 700: cx=536, cy=264
#
# 0: 640x384 2 goalkeepers, 24 players, 56.6ms
# Speed: 1.6ms preprocess, 56.6ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 384)
# Frame 337, Track 121: cx=-176, cy=534
# Frame 337, Track 177: cx=550, cy=293
# Frame 337, Track 442: cx=-244, cy=185
# Frame 337, Track 623: cx=634, cy=291
# Frame 337, Track 673: cx=358, cy=342
# Frame 337, Track 700: cx=537, cy=264
#
# 0: 640x384 3 goalkeepers, 25 players, 55.7ms
# Speed: 1.9ms preprocess, 55.7ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
# Frame 338, Track 121: cx=-180, cy=538
# Frame 338, Track 177: cx=550, cy=292
# Frame 338, Track 442: cx=-256, cy=183
# Frame 338, Track 623: cx=631, cy=289
# Frame 338, Track 673: cx=354, cy=345
# Frame 338, Track 700: cx=537, cy=263
#
# 0: 640x384 2 goalkeepers, 25 players, 55.7ms
# Speed: 1.8ms preprocess, 55.7ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
# Frame 339, Track 121: cx=-184, cy=541
# Frame 339, Track 177: cx=549, cy=291
# Frame 339, Track 442: cx=-267, cy=182
# Frame 339, Track 623: cx=606, cy=285
# Frame 339, Track 673: cx=350, cy=348
# Frame 339, Track 700: cx=538, cy=262
#
# 0: 640x384 2 goalkeepers, 27 players, 55.6ms
# Speed: 1.7ms preprocess, 55.6ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
# Frame 340, Track 121: cx=-188, cy=545
# Frame 340, Track 177: cx=549, cy=290
# Frame 340, Track 442: cx=-279, cy=179
# Frame 340, Track 623: cx=601, cy=284
# Frame 340, Track 673: cx=346, cy=351
# Frame 340, Track 700: cx=539, cy=261
#
# 0: 640x384 2 goalkeepers, 20 players, 55.7ms
# Speed: 1.9ms preprocess, 55.7ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 384)
# Frame 341, Track 121: cx=-192, cy=549
# Frame 341, Track 177: cx=548, cy=289
# Frame 341, Track 442: cx=-290, cy=178
# Frame 341, Track 623: cx=596, cy=282
# Frame 341, Track 673: cx=342, cy=355
# Frame 341, Track 700: cx=539, cy=260
#
# 0: 640x384 2 goalkeepers, 21 players, 64.7ms
# Speed: 2.1ms preprocess, 64.7ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 384)
# Frame 342, Track 121: cx=-196, cy=553
# Frame 342, Track 177: cx=548, cy=288
# Frame 342, Track 442: cx=-301, cy=176
# Frame 342, Track 623: cx=591, cy=281
# Frame 342, Track 673: cx=338, cy=358
# Frame 342, Track 700: cx=540, cy=260
#
# 0: 640x384 2 goalkeepers, 22 players, 67.5ms
# Speed: 1.8ms preprocess, 67.5ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 384)
# Frame 343, Track 177: cx=547, cy=287
# Frame 343, Track 442: cx=-313, cy=175
# Frame 343, Track 623: cx=586, cy=279
# Frame 343, Track 673: cx=334, cy=361
# Frame 343, Track 700: cx=540, cy=259
#
# 0: 640x384 3 goalkeepers, 15 players, 67.5ms
# Speed: 1.9ms preprocess, 67.5ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 384)
# Frame 344, Track 177: cx=546, cy=286
# Frame 344, Track 442: cx=-324, cy=173
# Frame 344, Track 623: cx=580, cy=277
# Frame 344, Track 673: cx=330, cy=364
# Frame 344, Track 700: cx=541, cy=258
#
# 0: 640x384 3 goalkeepers, 20 players, 67.6ms
# Speed: 1.9ms preprocess, 67.6ms inference, 2.7ms postprocess per image at shape (1, 3, 640, 384)
# Frame 345, Track 177: cx=546, cy=285
# Frame 345, Track 442: cx=-336, cy=171
# Frame 345, Track 623: cx=575, cy=276
# Frame 345, Track 673: cx=326, cy=367
# Frame 345, Track 700: cx=541, cy=257
#
# 0: 640x384 1 goalkeeper, 23 players, 66.1ms
# Speed: 1.8ms preprocess, 66.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
# Frame 346, Track 177: cx=545, cy=284
# Frame 346, Track 442: cx=-347, cy=169
# Frame 346, Track 623: cx=570, cy=274
# Frame 346, Track 673: cx=322, cy=371
# Frame 346, Track 700: cx=542, cy=257
#
# 0: 640x384 2 goalkeepers, 22 players, 62.1ms
# Speed: 1.7ms preprocess, 62.1ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
# Frame 347, Track 177: cx=545, cy=284
# Frame 347, Track 442: cx=-359, cy=167
# Frame 347, Track 623: cx=565, cy=272
# Frame 347, Track 673: cx=318, cy=374
# Frame 347, Track 700: cx=543, cy=256
#
# 0: 640x384 2 goalkeepers, 26 players, 62.0ms
# Speed: 1.8ms preprocess, 62.0ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
# Frame 348, Track 177: cx=544, cy=283
# Frame 348, Track 623: cx=560, cy=271
# Frame 348, Track 673: cx=314, cy=377
# Frame 348, Track 700: cx=543, cy=255
#
# 0: 640x384 2 goalkeepers, 24 players, 57.6ms
# Speed: 1.8ms preprocess, 57.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
# Frame 349, Track 177: cx=543, cy=282
# Frame 349, Track 623: cx=554, cy=269
# Frame 349, Track 673: cx=310, cy=380
# Frame 349, Track 700: cx=544, cy=254
#
# 0: 640x384 2 goalkeepers, 23 players, 56.7ms
# Speed: 1.8ms preprocess, 56.7ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
# Frame 350, Track 177: cx=543, cy=281
# Frame 350, Track 623: cx=549, cy=267
# Frame 350, Track 673: cx=306, cy=383
# Frame 350, Track 700: cx=544, cy=254
#
# 0: 640x384 1 goalkeeper, 24 players, 56.6ms
# Speed: 1.6ms preprocess, 56.6ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
# Frame 351, Track 177: cx=542, cy=280
# Frame 351, Track 623: cx=544, cy=265
# Frame 351, Track 673: cx=302, cy=386
# Frame 351, Track 700: cx=545, cy=253
#
# 0: 640x384 2 goalkeepers, 29 players, 56.6ms
# Speed: 2.0ms preprocess, 56.6ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
# Frame 352, Track 177: cx=542, cy=279
# Frame 352, Track 623: cx=539, cy=264
# Frame 352, Track 673: cx=298, cy=389
# Frame 352, Track 700: cx=545, cy=252
#
# 0: 640x384 2 goalkeepers, 20 players, 56.6ms
# Speed: 1.6ms preprocess, 56.6ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 384)
# Frame 353, Track 177: cx=541, cy=278
# Frame 353, Track 623: cx=533, cy=262
# Frame 353, Track 673: cx=294, cy=392
# Frame 353, Track 700: cx=546, cy=252
#
# 0: 640x384 2 goalkeepers, 25 players, 56.6ms
# Speed: 1.9ms preprocess, 56.6ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 384)
# Frame 354, Track 177: cx=541, cy=277
# Frame 354, Track 623: cx=529, cy=260
# Frame 354, Track 673: cx=290, cy=395
# Frame 354, Track 700: cx=547, cy=251
#
# 0: 640x384 2 goalkeepers, 26 players, 56.7ms
# Speed: 1.8ms preprocess, 56.7ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
# Frame 355, Track 177: cx=540, cy=277
# Frame 355, Track 623: cx=524, cy=259
# Frame 355, Track 673: cx=286, cy=398
# Frame 355, Track 700: cx=547, cy=250
#
# 0: 640x384 2 goalkeepers, 23 players, 58.8ms
# Speed: 2.0ms preprocess, 58.8ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
# Frame 356, Track 177: cx=540, cy=276
# Frame 356, Track 623: cx=518, cy=257
# Frame 356, Track 673: cx=282, cy=401
# Frame 356, Track 700: cx=548, cy=250
#
# 0: 640x384 2 goalkeepers, 23 players, 56.6ms
# Speed: 2.1ms preprocess, 56.6ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
# Frame 357, Track 177: cx=539, cy=275
# Frame 357, Track 623: cx=513, cy=255
# Frame 357, Track 673: cx=278, cy=405
# Frame 357, Track 700: cx=548, cy=249
#
# 0: 640x384 1 goalkeeper, 23 players, 56.6ms
# Speed: 1.9ms preprocess, 56.6ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
# Frame 358, Track 177: cx=539, cy=274
# Frame 358, Track 623: cx=508, cy=254
# Frame 358, Track 673: cx=274, cy=408
# Frame 358, Track 700: cx=549, cy=248
#
# 0: 640x384 2 goalkeepers, 24 players, 56.7ms
# Speed: 1.6ms preprocess, 56.7ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
# Frame 359, Track 177: cx=538, cy=273
# Frame 359, Track 623: cx=503, cy=252
# Frame 359, Track 673: cx=269, cy=411
# Frame 359, Track 700: cx=549, cy=247
#
# 0: 640x384 2 goalkeepers, 23 players, 56.7ms
# Speed: 1.9ms preprocess, 56.7ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
# Frame 360, Track 177: cx=538, cy=272
# Frame 360, Track 623: cx=498, cy=250
# Frame 360, Track 673: cx=265, cy=414
# Frame 360, Track 700: cx=550, cy=247
#
# 0: 640x384 3 goalkeepers, 23 players, 56.6ms
# Speed: 2.7ms preprocess, 56.6ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 384)
# Frame 361, Track 177: cx=537, cy=271
# Frame 361, Track 623: cx=492, cy=249
# Frame 361, Track 673: cx=261, cy=417
# Frame 361, Track 700: cx=551, cy=246
#
# 0: 640x384 3 goalkeepers, 27 players, 56.6ms
# Speed: 1.8ms preprocess, 56.6ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 384)
# Frame 362, Track 177: cx=537, cy=270
# Frame 362, Track 623: cx=487, cy=247
# Frame 362, Track 673: cx=257, cy=421
# Frame 362, Track 700: cx=551, cy=245
#
# 0: 640x384 3 goalkeepers, 25 players, 1 referee, 54.8ms
# Speed: 2.0ms preprocess, 54.8ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
# Frame 363, Track 177: cx=536, cy=269
# Frame 363, Track 623: cx=482, cy=245
# Frame 363, Track 673: cx=127, cy=285
# Frame 363, Track 700: cx=552, cy=244
#
# 0: 640x384 3 goalkeepers, 28 players, 54.8ms
# Speed: 2.1ms preprocess, 54.8ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
# Frame 364, Track 177: cx=536, cy=268
# Frame 364, Track 623: cx=477, cy=244
# Frame 364, Track 673: cx=126, cy=283
# Frame 364, Track 700: cx=552, cy=244
#
# 0: 640x384 2 goalkeepers, 28 players, 54.7ms
# Speed: 1.8ms preprocess, 54.7ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
# Frame 365, Track 177: cx=535, cy=268
# Frame 365, Track 623: cx=472, cy=242
# Frame 365, Track 673: cx=118, cy=282
# Frame 365, Track 700: cx=553, cy=243
#
# 0: 640x384 3 goalkeepers, 24 players, 54.7ms
# Speed: 1.8ms preprocess, 54.7ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
# Frame 366, Track 177: cx=534, cy=267
# Frame 366, Track 623: cx=467, cy=241
# Frame 366, Track 673: cx=111, cy=280
# Frame 366, Track 700: cx=553, cy=242
#
# 0: 640x384 3 goalkeepers, 22 players, 54.8ms
# Speed: 1.9ms preprocess, 54.8ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
# Frame 367, Track 177: cx=534, cy=266
# Frame 367, Track 623: cx=462, cy=239
# Frame 367, Track 673: cx=103, cy=278
# Frame 367, Track 700: cx=554, cy=241
#
# 0: 640x384 2 goalkeepers, 24 players, 54.8ms
# Speed: 1.9ms preprocess, 54.8ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 384)
# Frame 368, Track 177: cx=533, cy=265
# Frame 368, Track 623: cx=456, cy=237
# Frame 368, Track 673: cx=96, cy=277
# Frame 368, Track 700: cx=555, cy=240
#
# 0: 640x384 3 goalkeepers, 23 players, 57.0ms
# Speed: 1.6ms preprocess, 57.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
# Frame 369, Track 177: cx=533, cy=264
# Frame 369, Track 623: cx=451, cy=236
# Frame 369, Track 673: cx=88, cy=275
# Frame 369, Track 700: cx=555, cy=240
#
# 0: 640x384 3 goalkeepers, 26 players, 57.6ms
# Speed: 1.5ms preprocess, 57.6ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
# Frame 370, Track 177: cx=532, cy=263
# Frame 370, Track 623: cx=446, cy=234
# Frame 370, Track 673: cx=81, cy=273
# Frame 370, Track 700: cx=556, cy=239
#
# 0: 640x384 3 goalkeepers, 24 players, 58.1ms
# Speed: 1.6ms preprocess, 58.1ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 384)
# Frame 371, Track 177: cx=531, cy=262
# Frame 371, Track 623: cx=441, cy=232
# Frame 371, Track 673: cx=73, cy=271
# Frame 371, Track 700: cx=556, cy=238
#
# 0: 640x384 1 player, 58.7ms
# Speed: 1.8ms preprocess, 58.7ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
# Frame 372, Track 177: cx=531, cy=261
# Frame 372, Track 623: cx=435, cy=231
# Frame 372, Track 673: cx=66, cy=270
# Frame 372, Track 700: cx=556, cy=237
#
# 0: 640x384 2 players, 54.9ms
# Speed: 1.5ms preprocess, 54.9ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
# Frame 373, Track 177: cx=530, cy=260
# Frame 373, Track 623: cx=430, cy=229
# Frame 373, Track 673: cx=58, cy=268
# Frame 373, Track 700: cx=557, cy=237
#
# 0: 640x384 5 players, 54.8ms
# Speed: 1.7ms preprocess, 54.8ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
# Frame 374, Track 177: cx=530, cy=259
# Frame 374, Track 623: cx=425, cy=227
# Frame 374, Track 673: cx=51, cy=266
# Frame 374, Track 700: cx=558, cy=236
#
# 0: 640x384 (no detections), 54.9ms
# Speed: 2.0ms preprocess, 54.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# Frame 375, Track 177: cx=529, cy=259
# Frame 375, Track 623: cx=420, cy=226
# Frame 375, Track 673: cx=43, cy=264
# Frame 375, Track 700: cx=559, cy=236
# Video ended at frame 375
#
#  Tracking Complete: 10 unique players re-identified.
